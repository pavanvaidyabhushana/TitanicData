# %%
import numpy as np

# %%
import pandas as pd

# %%
data = pd.read_csv("C:\\Users\\pavan\\Desktop\\DataPortfolio\\Datasets\\Datasets-master\\Datasets-master\\titanic_data.csv")

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.catplot(data = data , x = "Sex", kind = "count").set(title="Count of Male&Female")

# %%
sns.catplot(data = data ,x = 'Sex' ,kind = 'count', hue = 'Pclass')

# %%
sns.catplot(data=data,x='Pclass',hue='Sex',kind='count')

# %%
sns.catplot(data = data, kind = "count" , x = "Survived").set(title = "Number of Survived")

# %%
sns.catplot(data = data, kind = "count" , x = "Sex" , hue = "Survived").set(title = "Number of Survived with Sex data")

# %%
def male_female_child(object):
    age,sex = object
    if age < 16:
        return 'child'
    else:
        return sex

# %%
data['person'] = data[['Age','Sex']].apply(male_female_child,axis=1)

# %%
data.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
sns.catplot(hue='person',x='Pclass',kind='count',data = data)

# %%
plt.hist(data.Age,bins = 70)
# Out:
# (array([14., 10.,  6., 10.,  7.,  3.,  4.,  8.,  2.,  4.,  1.,  8.,  6.,
#         17., 13., 26., 25., 16., 51., 15., 31., 24., 18., 18., 27., 20.,
#         44., 18., 17., 16., 18., 23.,  6., 25., 13.,  8., 13.,  5.,  9.,
#         14., 12.,  9.,  6., 10.,  7.,  6.,  1.,  8.,  7.,  2.,  5.,  2.,
#          4.,  3.,  4.,  4.,  3.,  1.,  0.,  0.,  0.,  3.,  2.,  0.,  1.,
#          0.,  0.,  0.,  0.,  1.]),
#  array([ 0.42      ,  1.55685714,  2.69371429,  3.83057143,  4.96742857,
#          6.10428571,  7.24114286,  8.378     ,  9.51485714, 10.65171429,
#         11.78857143, 12.92542857, 14.06228571, 15.19914286, 16.336     ,
#         17.47285714, 18.60971429, 19.74657143, 20.88342857, 22.02028571,
#         23.15714286, 24.294     , 25.43085714, 26.56771429, 27.70457143,
#         28.84142857, 29.97828571, 31.11514286, 32.252     , 33.38885714,
#         34.52571429, 35.66257143, 36.79942857, 37.93628571, 39.07314286,
# ...

# %%
data.Age.mean()
# Out:
# 29.69911764705882

# %%
data.person.value_counts()
# Out:
# male      537
# female    271
# child      83
# Name: person, dtype: int64

# %%
sns.catplot(data = data, kind = "count" , x = "Pclass" , hue = "Survived").set(title = "Number of Survived with Sex data")

# %%
sns.kdeplot(data.Age,shade=True)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
fig = sns.FacetGrid(data,hue='Sex',aspect=4)
fig.map(sns.kdeplot,'Age',shade=True)
oldest = data.Age.max()
fig.set(xlim=(0,oldest))
fig.add_legend()

# %%
fig = sns.FacetGrid(data,hue='person',aspect=4)
fig.map(sns.kdeplot,'Age',shade=True)
oldest = data.Age.max()
fig.set(xlim=(0,oldest))
fig.add_legend()

# %%
fig = sns.FacetGrid(data,hue='Pclass',aspect=4)
fig.map(sns.kdeplot,'Age',shade=True)
oldest = data.Age.max()
fig.set(xlim=(0,oldest))
fig.add_legend()

# %%
deck = data['Cabin'].dropna()

# %%
deck.head()
# Out:
# 1      C85
# 3     C123
# 6      E46
# 10      G6
# 11    C103
# Name: Cabin, dtype: object

# %%
levels = []

for level in deck:
    levels.append(level[0])
    
cabindf = pd.DataFrame(levels,columns=['Cabintype'])
sns.factorplot(kind='count',x='Cabintype',data=cabindf,palette='winter_d')
# Out:
# C:\Users\pavan\AppData\Roaming\Python\Python310\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
cabindf = cabindf[cabindf.Cabintype != 'T']
sns.factorplot(x='Cabintype',kind='count',data=cabindf,palette='summer')
# Out:
# C:\Users\pavan\AppData\Roaming\Python\Python310\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
sns.factorplot(x="Embarked",data= data,hue='Pclass',
               kind='count',palette='winter_d',
               order=['C','Q','S'])
# Out:
# C:\Users\pavan\AppData\Roaming\Python\Python310\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
data["Agegroup"] = pd.qcut(data["Age"],4)
sns.barplot(data = data , y = "Survived" , x = "Agegroup").set(title = "Survived wrt Age groups")
# Out:
# [Text(0.5, 1.0, 'Survived wrt Age groups')]

# %%
sns.catplot(data = data , x = "Pclass" , col= "Embarked" ,kind = "count" ,hue = "Survived")

# %%
sns.catplot(data = data , col = "Embarked" , hue = "Sex" , kind = "count" , x = "Survived").set(
    title = "No of male/female survived at Embarked position")

# %%
Family = data["Parch"] + data["SibSp"]
data = data.assign(Family_size = Family)
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
sns.barplot(data= data , x = "Family_size" , y = "Survived").set(
title = "% of ppl survived in each family depends on size")
# Out:
# [Text(0.5, 1.0, '% of ppl survived in each family depends on size')]

# %%
data.loc[data['Family_size'] == 0,'FamilySize'] = "Alone"
data.loc[data['Family_size'] != 0,'FamilySize'] = "Family"
sns.catplot(data = data , x = "FamilySize" , kind = "count" , hue = "Survived").set(
    title = "Survived ")

# %%
sns.factorplot(x='FamilySize',data = data,kind='count',palette='Blues')
# Out:
# C:\Users\pavan\AppData\Roaming\Python\Python310\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
data['Survival'] = data.Survived.map({0:'NO',1:'YES'})
sns.factorplot(x='Survival',data=data,kind='count',palette='Set1')
# Out:
# C:\Users\pavan\AppData\Roaming\Python\Python310\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
sns.factorplot(x='Pclass',y='Survived',hue='person',data=data)
# Out:
# C:\Users\pavan\AppData\Roaming\Python\Python310\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
sns.lmplot(data=data,x='Age',y='Survived')

# %%
sns.lmplot(data=data,x='Age',y='Survived',hue='Pclass')

# %%
generations = [20,40,60,80]
sns.lmplot(data=data,x='Age',y='Survived',x_bins=generations,hue='Pclass')

# %%
sns.lmplot(data=data,x='Age',y='Survived',hue='Sex',x_bins=generations,palette='winter_d')

# %%
sns.violinplot(data = data,x='Sex',y='Age',hue='Survived')
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Age'>

# %%
group = data.groupby(['Pclass','Survived'])
pclass_survived = group.size().unstack()
sns.heatmap(pclass_survived,fmt='d',annot=True)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='Pclass'>
